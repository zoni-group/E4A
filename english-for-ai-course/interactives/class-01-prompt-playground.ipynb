# %% [markdown]
# # Lessons 1-2 Colab Lab: Prompt Playground
#
# <figure>
# <a
# href="https://colab.research.google.com/github/zoni-group/E4A/blob/public-12db68dfaf5f/english-for-ai-course/interactives/class-01-prompt-playground.ipynb"><img
# src="https://colab.research.google.com/assets/colab-badge.svg" /></a>
# <figcaption>Open in Colab</figcaption>
# </figure>
#
# # Lessons 1-2 Colab Lab: Prompt Playground
#
# ## What you will do
#
# In this lab you will build a **ZONI CLEAR prompt** in English, step by
# step.
#
# You will:
#
# 1.  Choose a safe everyday task.
# 2.  Add context, limits, and an output format.
# 3.  Build a finished prompt.
# 4.  Ask Colab AI for a short demo answer (if AI is available).
# 5.  Save your prompt in your portfolio.
#
# You do **not** need to know Python. Just **Run this cell** when you see
# the words.
#
# > ⚠️ **Privacy warning**
# >
# > Do not type private information into this notebook. Do not write real
# > names, addresses, ID numbers, passwords, school records, medical
# > records, immigration documents, or employer documents. Use safe
# > examples only.
#
# ## Step 1. Start the lab
#
# Run this cell. It loads the lab helpers and uses **Colab AI
# automatically** when it is available. If the helper or Colab AI cannot
# load, you will see a short, friendly message — the regular lab steps
# will still work.

# %%
# @title Step 1: Start the lab
import urllib.request
HELPER_URL = "https://raw.githubusercontent.com/zoni-group/E4A/public-12db68dfaf5f/english-for-ai-course/interactives/e4a_colab.py"
try: exec(urllib.request.urlopen(HELPER_URL, timeout=10).read().decode("utf-8"))
except Exception: exec("from IPython.display import Markdown,display\nM='The lab helper could not load. This may be a network problem. Ask your teacher, or use the regular worksheet steps. You did not break anything.'\ndef show(x): display(Markdown(str(x)))\ndef _fb(*a,**k): return M\nshow_ai_answer=lambda t,a: show('**'+str(t)+':**\\n\\n```text\\n'+str(a)+'\\n```')\nshow_portfolio_markdown=lambda md: show('### Copy this to your portfolio\\n\\n```markdown\\n'+str(md)+'\\n```')\nshow_ai_check_block=lambda: show('### Check the AI answer\\n\\nAI can help, but I must check it.\\n\\n1. Did AI use only safe information?\\n2. Did AI invent anything?\\n3. What should I verify?\\n4. What will I keep, change, or reject?\\n5. I make the final decision.')\ndef verify_quote_in_source(q,s):\n ok=bool(q) and ' '.join(str(q).split()).lower() in ' '.join(str(s).split()).lower(); show('✅ Yes, this quote appears in the source.' if ok else '⚠️ Check again. This quote was not found in the source.'); return ok\nsafe_ai_response=ai_review_prompt=ai_review_decision_matrix=ai_answer_from_source=ai_review_script=ai_review_workflow=_fb\nstart_e4a_lab=lambda lab_id: show('### Lab helper offline\\n\\n'+M+'\\n\\nYou can still complete this lab using the regular worksheet steps in the book.')")
start_e4a_lab("class-01")

# %% [markdown]
# ## Step 2. Edit the safe example
#
# Edit the values inside the quotes. Use a safe everyday task only.
#
# Safe task ideas:
#
# - `"Make a simple study plan for an English test."`
# - `"Write a polite email to ask my teacher a question."`
# - `"Plan a small grocery list for one week."`
# - `"Practice interview answers about my study goals."`
# - `"Understand a short public announcement."`

# %%
# @title Step 2: Edit the safe example
task = "Make a simple study plan for an English test."
context = "I can study 30 minutes a day. I want help with vocabulary and speaking."
limit_1 = "Use simple English."
limit_2 = "Do not invent facts."
limit_3 = "Do not use private information."
limit_4 = "Ask questions if information is missing."
output_format = "A 4-day study plan as a short table."

# %% [markdown]
# ## Step 3. Build my ZONI CLEAR prompt
#
# Run this cell to put your ZONI CLEAR prompt together.

# %%
# @title Step 3: Build my ZONI CLEAR prompt
limits_block = "- " + limit_1 + "\n- " + limit_2 + "\n- " + limit_3 + "\n- " + limit_4
prompt_text = (
    "I need help with: " + task + "\n\n"
    "Context:\n" + context + "\n\n"
    "Limits:\n" + limits_block + "\n\n"
    "Output format:\n" + output_format + "\n\n"
    "Before answering:\n"
    "List anything that is missing or unclear."
)
show("**Your ZONI CLEAR prompt:**\n\n```text\n" + prompt_text + "\n```")

# %% [markdown]
# ## Step 4. Use Colab AI to review
#
# Colab AI is used **automatically** when it is available. If AI is not
# available, you will see a short message and the regular lab steps still
# work.
#
# > ⚠️ **Privacy warning:** do not type private information. AI may be
# > wrong. Always check important answers.

# %%
# @title Step 4: Use Colab AI to review
ai_demo_answer = ai_review_prompt(prompt_text)
show_ai_answer("Colab AI demo answer", ai_demo_answer)

# %% [markdown]
# ### Check the AI answer
#
# AI can help, but I must check it.
#
# 1.  Did AI use only safe information?
# 2.  Did AI invent anything?
# 3.  What should I verify?
# 4.  What will I keep, change, or reject?
# 5.  I make the final decision.
#
# ## Step 5. Check the AI answer in writing
#
# Write a short answer for each check question.

# %%
# @title Step 5: Check the AI answer
ai_check_safe = "AI used safe information about study time."
ai_check_changed = "I changed the schedule to fit my work hours."
ai_check_verify = "I will verify the test date with my teacher."
show(
    "**My AI check:**\n\n"
    "- Safe: " + ai_check_safe + "\n"
    "- Changed: " + ai_check_changed + "\n"
    "- Verify: " + ai_check_verify
)

# %% [markdown]
# ## Step 6. Privacy check
#
# Write one short sentence about what private information you removed from
# your prompt.

# %%
# @title Step 6: Privacy check
private_info_removed = "I removed my school name and my real address."
show("**Privacy check:** " + private_info_removed)

# %% [markdown]
# ## Step 7. Copy this to my portfolio
#
# Run this cell. Copy the Markdown text that appears.
#
# Save the result to your portfolio as:
#
# `English AI Decision Toolkit/Lesson 1 - My First Safe English AI Prompt and Privacy Check.md`

# %%
# @title Step 7: Copy this to my portfolio
portfolio_md = (
    "# Lesson 1 - My First Safe English AI Prompt and Privacy Check\n\n"
    "## My motivation\n\n"
    "AI can help me practice English, but I need to use it safely.\n\n"
    "## My AI privacy check\n\n"
    "I looked for Privacy, Data Controls, Training, Chat history, and Personalization.\n"
    "I wrote what I found, or I wrote: I could not find this setting.\n\n"
    "## My task\n\n" + task + "\n\n"
    "## My prompt\n\n"
    "```text\n" + prompt_text + "\n```\n\n"
    "## AI demo answer (for review)\n\n"
    "```text\n" + str(ai_demo_answer) + "\n```\n\n"
    "## My AI check\n\n"
    "- Safe: " + ai_check_safe + "\n"
    "- Changed: " + ai_check_changed + "\n"
    "- Verify: " + ai_check_verify + "\n\n"
    "## Words I learned\n\n"
    "1.\n2.\n3.\n\n"
    "## What I did not share\n\n"
    + private_info_removed + "\n"
    "\n## My safety rule\n\n"
    "If the task includes private information, I will use a fake example or ask my teacher for a safe practice task.\n"
)
show_portfolio_markdown(portfolio_md)

# %% [markdown]
# ## Save your work
#
# 1.  Copy the Markdown text above.
# 2.  Paste it into a new file called
#     `Lesson 1 - My First Safe English AI Prompt and Privacy Check.md`.
# 3.  Save the file in your `English AI Decision Toolkit` folder.
#
# > Remember: AI can help you think and write in English. You make the
# > final decision.
