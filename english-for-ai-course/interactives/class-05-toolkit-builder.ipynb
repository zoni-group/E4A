# %% [markdown]
# # Lessons 9-10 Colab Lab: English AI Decision Toolkit Builder
#
# <figure>
# <a
# href="https://colab.research.google.com/github/zoni-group/E4A/blob/public-e1c770cec3c5/english-for-ai-course/interactives/class-05-toolkit-builder.ipynb"><img
# src="https://colab.research.google.com/assets/colab-badge.svg" /></a>
# <figcaption>Open in Colab</figcaption>
# </figure>
#
# # Lessons 9-10 Colab Lab: English AI Decision Toolkit Builder
#
# ## What you will do
#
# You will assemble your final **English AI Decision Toolkit**.
#
# You will:
#
# 1.  Check that you have all required portfolio files.
# 2.  Build a personal AI safety checklist.
# 3.  Build a short AI decision assistant prompt.
# 4.  Write a final reflection in simple English.
# 5.  Ask Colab AI for a short review of your workflow (if AI is
#     available).
# 6.  Copy three Markdown files to your portfolio.
#
# You do **not** need to know Python. Just **Run this cell** when you see
# the words.
#
# > ⚠️ **Privacy warning**
# >
# > Do not type private information into this notebook. Keep all examples
# > safe and general.
#
# ## Step 1. Start the lab
#
# Run this cell. It loads the lab helpers and uses **Colab AI
# automatically** when it is available. If the helper or Colab AI cannot
# load, you will see a short, friendly message — the regular lab steps
# will still work.

# %%
# @title Step 1: Start the lab
import urllib.request
HELPER_URL = "https://raw.githubusercontent.com/zoni-group/E4A/public-e1c770cec3c5/english-for-ai-course/interactives/e4a_colab.py"
try: exec(urllib.request.urlopen(HELPER_URL, timeout=10).read().decode("utf-8"))
except Exception: exec("from IPython.display import Markdown,display\nM='The lab helper could not load. This may be a network problem. Ask your teacher, or use the regular worksheet steps. You did not break anything.'\ndef show(x): display(Markdown(str(x)))\ndef _fb(*a,**k): return M\nshow_ai_answer=lambda t,a: show('**'+str(t)+':**\\n\\n```text\\n'+str(a)+'\\n```')\nshow_portfolio_markdown=lambda md: show('### Copy this to your portfolio\\n\\n```markdown\\n'+str(md)+'\\n```')\nshow_ai_check_block=lambda: show('### Check the AI answer\\n\\nAI can help, but I must check it.\\n\\n1. Did AI use only safe information?\\n2. Did AI invent anything?\\n3. What should I verify?\\n4. What will I keep, change, or reject?\\n5. I make the final decision.')\ndef verify_quote_in_source(q,s):\n ok=bool(q) and ' '.join(str(q).split()).lower() in ' '.join(str(s).split()).lower(); show('✅ Yes, this quote appears in the source.' if ok else '⚠️ Check again. This quote was not found in the source.'); return ok\nsafe_ai_response=ai_review_prompt=ai_review_decision_matrix=ai_answer_from_source=ai_review_script=ai_review_workflow=_fb\nstart_e4a_lab=lambda lab_id: show('### Lab helper offline\\n\\n'+M+'\\n\\nYou can still complete this lab using the regular worksheet steps in the book.')")
start_e4a_lab("class-05")

# %% [markdown]
# ## Step 2. Load the portfolio checklist

# %%
# @title Step 2: Load the portfolio checklist
PORTFOLIO_FILES = [
    "Lesson 1 - My First Safe English AI Prompt and Privacy Check.md",
    "Lesson 2 - Prompt Practice and Vocabulary Log.md",
    "Lesson 3 - English Decision Matrix.md",
    "Lesson 4 - Revised Prompt and Decision Matrix.md",
    "Lesson 5 - Source-Grounded Answer in English.md",
    "Lesson 6 - Source Check and Paraphrase.md",
    "Lesson 7 - Visual Description and Attribution Note.md",
    "Lesson 8 - Speaking Script and Consent Check.md",
    "Lesson 9 - Presentation Draft and Portfolio Checklist.md",
    "Lesson 10 - My AI Decision Assistant Prompt.md",
    "Lesson 10 - Final Project - My English AI Workflow.md",
    "Vocabulary Log.md",
    "Sentence Frames I Can Use.md",
    "Personal AI Safety Checklist.md",
]
show("Loaded portfolio checklist with " + str(len(PORTFOLIO_FILES)) + " files.")

# %% [markdown]
# ## Step 3. Mark which files I have saved
#
# Mark `True` for files you have already saved. Mark `False` for files you
# still need to write.

# %%
# @title Step 3: Mark which files I have saved
i_have_saved = {
    "Lesson 1 - My First Safe English AI Prompt and Privacy Check.md": True,
    "Lesson 2 - Prompt Practice and Vocabulary Log.md": True,
    "Lesson 3 - English Decision Matrix.md": True,
    "Lesson 4 - Revised Prompt and Decision Matrix.md": True,
    "Lesson 5 - Source-Grounded Answer in English.md": True,
    "Lesson 6 - Source Check and Paraphrase.md": True,
    "Lesson 7 - Visual Description and Attribution Note.md": True,
    "Lesson 8 - Speaking Script and Consent Check.md": True,
    "Lesson 9 - Presentation Draft and Portfolio Checklist.md": True,
    "Lesson 10 - My AI Decision Assistant Prompt.md": False,
    "Lesson 10 - Final Project - My English AI Workflow.md": False,
    "Vocabulary Log.md": True,
    "Sentence Frames I Can Use.md": True,
    "Personal AI Safety Checklist.md": False,
}

# %% [markdown]
# ## Step 4. Build my portfolio status

# %%
# @title Step 4: Build my portfolio status
status_lines = []
for name in PORTFOLIO_FILES:
    mark = "x" if i_have_saved.get(name, False) else " "
    status_lines.append("- [" + mark + "] " + name)
status_md = "\n".join(status_lines)

missing = [n for n in PORTFOLIO_FILES if not i_have_saved.get(n, False)]
show(
    "**Portfolio status**\n\n" + status_md
    + "\n\n**Files still to save:** " + str(len(missing))
)

# %% [markdown]
# ## Step 5. Build my Personal AI Safety Checklist
#
# Edit one line per rule. Keep rules short.

# %%
# @title Step 5: Build my Personal AI Safety Checklist
safety_1 = "I do not share private information with AI."
safety_2 = "I do not upload private documents to AI."
safety_3 = "I check privacy/data settings and opt out where the tool allows it."
safety_4 = "I know opting out is helpful but not enough."
safety_5 = "I check important answers in a real source."
safety_6 = "I write in simple English."
safety_7 = "I make the final decision myself."
safety_8 = "I ask my teacher or a trusted person if I am not sure."

# %% [markdown]
# ## Step 6. Build my AI decision assistant prompt
#
# Edit one line per rule. Keep rules short.

# %%
# @title Step 6: Build my AI decision assistant prompt
assistant_purpose = "Help me make safe everyday decisions in simple English."
assistant_rule_1 = "Use simple English."
assistant_rule_2 = "Ask me 3 short questions before giving advice."
assistant_rule_3 = "List the facts I know and what is missing."
assistant_rule_4 = "Do not use my private information."
assistant_rule_5 = "Remind me that I make the final decision."
assistant_rule_6 = "Remind me to check privacy/data settings and not share private information."

# %% [markdown]
# ## Step 7. Edit my reflection

# %%
# @title Step 7: Edit my reflection
reflection_can_use = "plan study time and write polite emails"
reflection_practice = "speaking with longer sentences"
reflection_safety = "I never paste private documents into AI tools"

# %% [markdown]
# ## Step 8. Use Colab AI to review my workflow
#
# Colab AI is used **automatically** when it is available. AI gives a
# short review of your assistant prompt and reflection. AI must **not**
# write your final portfolio for you, and AI must **not** say your work is
# finished.
#
# > ⚠️ **Privacy warning:** do not type private information. AI is a
# > reviewer, not a certifier. You decide what is finished.

# %%
# @title Step 8: Use Colab AI to review my workflow
workflow_summary = (
    "Assistant purpose: " + assistant_purpose + "\n\n"
    "Assistant rules:\n"
    "- " + assistant_rule_1 + "\n"
    "- " + assistant_rule_2 + "\n"
    "- " + assistant_rule_3 + "\n"
    "- " + assistant_rule_4 + "\n"
    "- " + assistant_rule_5 + "\n"
    "- " + assistant_rule_6 + "\n\n"
    "Reflection:\n"
    "- Can use AI to: " + reflection_can_use + "\n"
    "- Still need to practice: " + reflection_practice + "\n"
    "- One safety rule: " + reflection_safety
)
ai_workflow_review = ai_review_workflow(workflow_summary)
show_ai_answer("Colab AI workflow review", ai_workflow_review)

# %% [markdown]
# ### Check the AI answer
#
# AI can help, but I must check it.
#
# 1.  Did AI use only safe information?
# 2.  Did AI invent anything?
# 3.  What should I verify?
# 4.  What will I keep, change, or reject?
# 5.  I make the final decision.
#
# ## Step 9. Check the AI answer in writing

# %%
# @title Step 9: Check the AI answer
ai_check_useful = "AI noticed I forgot to add a 'save outside the AI tool' step."
ai_check_rejected = "I did not use the part where AI said my reflection was finished."
ai_check_verify = "I will verify that my final project file is saved."
show(
    "**My AI check:**\n\n"
    "- Useful: " + ai_check_useful + "\n"
    "- Rejected: " + ai_check_rejected + "\n"
    "- Verify: " + ai_check_verify
)

# %% [markdown]
# ## Step 10. Copy this to my portfolio
#
# Run this cell. Copy each of the three Markdown blocks into its own file.

# %%
# @title Step 10: Copy this to my portfolio
safety_md = (
    "# Personal AI Safety Checklist\n\n"
    "These are the rules I follow when I use AI in English.\n\n"
    "- [ ] " + safety_1 + "\n"
    "- [ ] " + safety_2 + "\n"
    "- [ ] " + safety_3 + "\n"
    "- [ ] " + safety_4 + "\n"
    "- [ ] " + safety_5 + "\n"
    "- [ ] " + safety_6 + "\n"
    "- [ ] " + safety_7 + "\n"
    "- [ ] " + safety_8 + "\n"
)

assistant_prompt = (
    "I want a personal AI decision assistant.\n\n"
    "Purpose:\n" + assistant_purpose + "\n\n"
    "Rules:\n"
    "- " + assistant_rule_1 + "\n"
    "- " + assistant_rule_2 + "\n"
    "- " + assistant_rule_3 + "\n"
    "- " + assistant_rule_4 + "\n"
    "- " + assistant_rule_5 + "\n"
    "- " + assistant_rule_6 + "\n\n"
    "Output format:\n"
    "- Short bullet list in simple English.\n"
    "- List of any missing information.\n"
    "- A clear reminder that I make the final decision."
)

assistant_md = (
    "# Lesson 10 - My AI Decision Assistant Prompt\n\n"
    "```text\n" + assistant_prompt + "\n```\n"
)

final_project_md = (
    "# Lesson 10 - Final Project - My English AI Workflow\n\n"
    "## My workflow in simple English\n\n"
    "1. I write a clear English prompt.\n"
    "2. I check what is private and remove it.\n"
    "3. I compare options in a small matrix.\n"
    "4. I check important answers in a real source.\n"
    "5. I describe visuals and practice speaking.\n"
    "6. I save my work in my portfolio.\n"
    "7. I make the final decision myself.\n\n"
    "## Reflection\n\n"
    "- I can use AI in English to **" + reflection_can_use + "**.\n"
    "- I still need to practice **" + reflection_practice + "**.\n"
    "- One safety rule I will remember is: **" + reflection_safety + "**.\n\n"
    "## AI workflow review (for review only)\n\n"
    "```text\n" + str(ai_workflow_review) + "\n```\n\n"
    "## My AI check\n\n"
    "- Useful: " + ai_check_useful + "\n"
    "- Rejected: " + ai_check_rejected + "\n"
    "- Verify: " + ai_check_verify + "\n\n"
    "## Portfolio status\n\n" + status_md + "\n"
)

show(
    "### File 1. Copy this to your portfolio\n\n"
    "Save as `Personal AI Safety Checklist.md`.\n\n"
    "```markdown\n" + safety_md + "\n```\n\n"
    "### File 2. Copy this to your portfolio\n\n"
    "Save as `Lesson 10 - My AI Decision Assistant Prompt.md`.\n\n"
    "```markdown\n" + assistant_md + "\n```\n\n"
    "### File 3. Copy this to your portfolio\n\n"
    "Save as `Lesson 10 - Final Project - My English AI Workflow.md`.\n\n"
    "```markdown\n" + final_project_md + "\n```"
)

# %% [markdown]
# ## Save your work
#
# 1.  Copy each Markdown block above into its own file.
# 2.  Save the files in your `English AI Decision Toolkit` folder.
# 3.  Re-check the portfolio status. All boxes should be filled.
#
# > Remember: This toolkit is yours. AI helps you in English. You make the
# > final decision.
