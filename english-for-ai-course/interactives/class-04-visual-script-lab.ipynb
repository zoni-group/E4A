# %% [markdown]
# # Class 4 Colab Lab: Visual Description and 60-Second Script
#
# <figure>
# <a
# href="https://colab.research.google.com/github/zoni-group/E4A/blob/public-066129daaf2c/english-for-ai-course/interactives/class-04-visual-script-lab.ipynb"><img
# src="https://colab.research.google.com/assets/colab-badge.svg" /></a>
# <figcaption>Open in Colab</figcaption>
# </figure>
#
# # Class 4 Colab Lab: Visual Description and 60-Second Script
#
# ## What you will do
#
# You will describe a safe visual and write a short speaking script.
#
# You will:
#
# 1.  Pick a safe visual topic.
# 2.  Describe what the visual shows.
# 3.  Add visual attribution fields.
# 4.  Write a 60-second speaking script.
# 5.  Ask Colab AI to suggest a simpler script (if AI is available).
# 6.  Choose one pronunciation focus.
# 7.  Confirm consent and source.
# 8.  Save your work in your portfolio.
#
# You do **not** need to know Python. Just **Run this cell** when you see
# the words.
#
# > ⚠️ **Privacy warning**
# >
# > Do not upload images, photos, or audio to this notebook. Do not
# > describe a real person without their consent. Use safe public-style
# > topics only.
#
# ## Step 1. Start the lab
#
# Run this cell. It loads the lab helpers and uses **Colab AI
# automatically** when it is available. If the helper or Colab AI cannot
# load, you will see a short, friendly message — the regular lab steps
# will still work.

# %%
# @title Step 1: Start the lab
import urllib.request
HELPER_URL = "https://raw.githubusercontent.com/zoni-group/E4A/public-066129daaf2c/english-for-ai-course/interactives/e4a_colab.py"
try: exec(urllib.request.urlopen(HELPER_URL, timeout=10).read().decode("utf-8"))
except Exception: exec("from IPython.display import Markdown,display\nM='The lab helper could not load. This may be a network problem. Ask your teacher, or use the regular worksheet steps. You did not break anything.'\ndef show(x): display(Markdown(str(x)))\ndef _fb(*a,**k): return M\nshow_ai_answer=lambda t,a: show('**'+str(t)+':**\\n\\n```text\\n'+str(a)+'\\n```')\nshow_portfolio_markdown=lambda md: show('### Copy this to your portfolio\\n\\n```markdown\\n'+str(md)+'\\n```')\nshow_ai_check_block=lambda: show('### Check the AI answer\\n\\nAI can help, but I must check it.\\n\\n1. Did AI use only safe information?\\n2. Did AI invent anything?\\n3. What should I verify?\\n4. What will I keep, change, or reject?\\n5. I make the final decision.')\ndef verify_quote_in_source(q,s):\n ok=bool(q) and ' '.join(str(q).split()).lower() in ' '.join(str(s).split()).lower(); show('✅ Yes, this quote appears in the source.' if ok else '⚠️ Check again. This quote was not found in the source.'); return ok\nsafe_ai_response=ai_review_prompt=ai_review_decision_matrix=ai_answer_from_source=ai_review_script=ai_review_workflow=_fb\nstart_e4a_lab=lambda lab_id: show('### Lab helper offline\\n\\n'+M+'\\n\\nYou can still complete this lab using the regular worksheet steps in the book.')")
start_e4a_lab("class-04")

# %% [markdown]
# ## Step 2. Edit the safe example
#
# Pick a safe visual topic.
#
# Safe topic ideas:
#
# - `"study group flyer"`
# - `"AI privacy poster"`
# - `"community event sign"`
# - `"library reading challenge poster"`
# - `"recycling guide poster"`
# - `"language exchange flyer"`

# %%
# @title Step 2: Edit the safe example
visual_topic = "study group flyer"
purpose = "Tell English learners about a free weekly study group at the library."
text_on_visual = (
    "Free English Study Group. Saturdays 3:00 PM at the public library. "
    "All levels welcome. Bring your notebook."
)
# Choose one: "self-created", "teacher-provided", "ZONI-provided course image", "open-license image"
source_choice = "ZONI-provided course image"
visual_title = "ZONI course image"
creator_or_author = "ZONI®"
source_or_url = "English for AI course materials"
license_or_permission = "ZONI course asset. Public viewing only under the repository license."
changes_made = "none"
attribution_note = "Image source: ZONI® course asset. Used for classroom practice."

# %% [markdown]
# ## Step 3. Build my visual description

# %%
# @title Step 3: Build my visual description
valid_sources = ["self-created", "teacher-provided", "ZONI-provided course image", "open-license image"]
clean_source = source_choice if source_choice in valid_sources else "ZONI-provided course image"

description = (
    "**The image shows:** " + visual_topic + ".\n\n"
    "**The purpose is:** " + purpose + "\n\n"
    "**The text says:** \"" + text_on_visual + "\"\n\n"
    "**Source:** " + clean_source + "\n\n"
    "**Visual attribution:**\n"
    "- Title: " + visual_title + "\n"
    "- Creator: " + creator_or_author + "\n"
    "- Source: " + source_or_url + "\n"
    "- License or permission: " + license_or_permission + "\n"
    "- Changes made: " + changes_made + "\n"
    "- Attribution note: " + attribution_note
)
show(description)

# %% [markdown]
# ## Step 4. Edit my 60-second speaking script
#
# A 60-second script is around **100 to 150 words**. Read it out loud once
# before saving.

# %%
# @title Step 4: Edit my 60-second speaking script
script_text = (
    "Hello, my name is Student A. Today I will describe this study group flyer. "
    "The image shows a simple flyer for a free English study group at the public "
    "library. The purpose is to invite English learners of all levels. "
    "The flyer says the group meets on Saturdays at three in the afternoon. "
    "Students bring a notebook. The image uses simple words and clear colors. "
    "It does not show personal photos or private information. I like this flyer "
    "because it is short, friendly, and easy to read. After this presentation, I "
    "will share the flyer with one friend who wants to practice English with me. "
    "Thank you for listening."
)

# %% [markdown]
# ## Step 5. Check the script length

# %%
# @title Step 5: Check the script length
word_count = len([w for w in script_text.split() if w.strip()])

if 100 <= word_count <= 150:
    length_note = "✅ Good length: " + str(word_count) + " words (about 60 seconds)."
elif word_count < 100:
    length_note = "⚠️ Short script: " + str(word_count) + " words. Add a sentence."
else:
    length_note = "⚠️ Long script: " + str(word_count) + " words. Cut one sentence."

show("**Word count:** " + length_note)

# %% [markdown]
# ## Step 6. Use Colab AI to review my script
#
# Colab AI is used **automatically** when it is available. AI will suggest
# a simpler version of your script. AI must **not** generate an image,
# describe a real person, or add facts.
#
# > ⚠️ **Privacy warning:** do not type private information. Do not paste
# > private photos, audio, or real names. AI may add details that are not
# > true — always check.

# %%
# @title Step 6: Use Colab AI to review my script
ai_script_suggestion = ai_review_script(script_text)
show_ai_answer("Colab AI script suggestion", ai_script_suggestion)

# %% [markdown]
# ### Check the AI answer
#
# AI can help, but I must check it.
#
# 1.  Did AI use only safe information?
# 2.  Did AI invent anything?
# 3.  What should I verify?
# 4.  What will I keep, change, or reject?
# 5.  I make the final decision.
#
# ## Step 7. Check the AI answer in writing

# %%
# @title Step 7: Check the AI answer
ai_check_useful = "AI made two sentences shorter and clearer."
ai_check_rejected = "I did not use the part where AI added a real-sounding name."
ai_check_verify = "I will verify the meeting time is still correct in my script."
show(
    "**My AI check:**\n\n"
    "- Useful: " + ai_check_useful + "\n"
    "- Rejected: " + ai_check_rejected + "\n"
    "- Verify: " + ai_check_verify
)

# %% [markdown]
# ## Step 8. Choose my pronunciation focus
#
# Pick ONE focus. Read the script three times with that focus.

# %%
# @title Step 8: Choose my pronunciation focus
# Choose ONE: "final consonants", "word stress", "pausing", "intonation"
pronunciation_focus = "pausing"

if pronunciation_focus == "final consonants":
    tip = "Say the last sound in each word clearly. Example: \"book\", not \"boo\"."
elif pronunciation_focus == "word stress":
    tip = "Make one syllable in each word a little longer and louder."
elif pronunciation_focus == "intonation":
    tip = "Your voice can go up at a question and down at the end of a statement."
else:
    tip = "Pause for one short breath after each sentence."

show("**My pronunciation focus:** " + pronunciation_focus + "\n\n**Tip:** " + tip)

# %% [markdown]
# ## Step 9. Consent reminder

# %%
# @title Step 9: Consent reminder
consent_sentence = "I do not show real people's faces or names. The visual is safe to share."
show("**Consent reminder:** " + consent_sentence)

# %% [markdown]
# ## Step 10. Copy this to my portfolio
#
# Run this cell. Copy the Markdown text that appears.
#
# Save the result to your portfolio as:
#
# `English AI Decision Toolkit/Class 4 - Visual Description and 60-Second Script.md`

# %%
# @title Step 10: Copy this to my portfolio
portfolio_md = (
    "# Class 4 - Visual Description and 60-Second Script\n\n"
    "## Visual topic\n\n" + visual_topic + "\n\n"
    "## Visual description\n\n"
    "- The image shows: " + visual_topic + ".\n"
    "- The purpose is: " + purpose + "\n"
    "- The text says: \"" + text_on_visual + "\"\n"
    "- Source: " + clean_source + "\n\n"
    "## Visual attribution\n\n"
    "Title: " + visual_title + "\n\n"
    "Creator: " + creator_or_author + "\n\n"
    "Source: " + source_or_url + "\n\n"
    "License or permission: " + license_or_permission + "\n\n"
    "Changes made: " + changes_made + "\n\n"
    "Attribution note: " + attribution_note + "\n\n"
    "## 60-second speaking script\n\n" + script_text + "\n\n"
    "**Word count:** " + str(word_count) + "\n\n"
    "## AI script suggestion (for review)\n\n"
    "```text\n" + str(ai_script_suggestion) + "\n```\n\n"
    "## My AI check\n\n"
    "- Useful: " + ai_check_useful + "\n"
    "- Rejected: " + ai_check_rejected + "\n"
    "- Verify: " + ai_check_verify + "\n\n"
    "## Pronunciation focus\n\n"
    "- Focus: " + pronunciation_focus + "\n"
    "- Tip: " + tip + "\n\n"
    "## Consent and source\n\n" + consent_sentence + "\n"
)
show_portfolio_markdown(portfolio_md)

# %% [markdown]
# ## Save your work
#
# 1.  Copy the Markdown text above.
# 2.  Paste it into a new file called
#     `Class 4 - Visual Description and 60-Second Script.md`.
# 3.  Save the file in your `English AI Decision Toolkit` folder.
#
# > Remember: Use safe visuals. Speak slowly. Pause between sentences.
