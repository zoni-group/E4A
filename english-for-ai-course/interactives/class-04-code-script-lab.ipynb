# %% [markdown]
# # Lessons 7-8 Colab Lab: Code Prompt and Project Speaking
#
# <figure>
# <a
# href="https://colab.research.google.com/github/zoni-group/E4A/blob/public-9c3abe1ad5b9/english-for-ai-course/interactives/class-04-code-script-lab.ipynb"><img
# src="https://colab.research.google.com/assets/colab-badge.svg" /></a>
# <figcaption>Open in Colab</figcaption>
# </figure>
#
# # Lessons 7-8 Colab Lab: Code Prompt and Project Speaking
#
# ## What you will do
#
# You will plan the English for an AI coding prompt and a 60-second
# project description.
#
# You will:
#
# 1.  choose a game, webpage, or application;
# 2.  name its goal and features;
# 3.  build a complete-file prompt as text;
# 4.  write one expected result and one possible bug report;
# 5.  plan two version filenames;
# 6.  prepare a short speaking script;
# 7.  ask Colab AI for English feedback, when it is available;
# 8.  experiment with the plan and run the cells again.
#
# This lab is a **playground** for English practice. It does not generate
# or run a game. You do not need GitHub, a terminal, an IDE, or other
# coding tools.
#
# > ⚠️ **Privacy warning**
# >
# > Do not upload HTML files, images, photos, audio, or private documents.
# > Do not type private information. Use a safe fictional project.
#
# ## Step 1. Start the lab
#
# Run this cell. It loads the lab helpers and uses **Colab AI
# automatically** when it is available. If the helper or Colab AI cannot
# load, you will see a short, friendly message — the regular lab steps
# will still work.

# %%
# @title Step 1: Start the lab
import urllib.request
HELPER_URL = "https://raw.githubusercontent.com/zoni-group/E4A/public-9c3abe1ad5b9/english-for-ai-course/interactives/e4a_colab.py"
try: exec(urllib.request.urlopen(HELPER_URL, timeout=10).read().decode("utf-8"))
except Exception: exec("from IPython.display import Markdown,display\nM='The lab helper could not load. This may be a network problem. Ask your teacher, or use the regular worksheet steps. You did not break anything.'\ndef show(x): display(Markdown(str(x)))\ndef _fb(*a,**k): return M\nshow_ai_answer=lambda t,a: show('**'+str(t)+':**\\n\\n```text\\n'+str(a)+'\\n```')\nshow_ai_check_block=lambda: show('### Check the AI answer\\n\\nAI can help, but I must check it.\\n\\n1. Did AI use only safe information?\\n2. Did AI invent anything?\\n3. What should I verify?\\n4. What will I keep, change, or reject?\\n5. I make the final decision.')\ndef verify_quote_in_source(q,s):\n ok=bool(q) and ' '.join(str(q).split()).lower() in ' '.join(str(s).split()).lower(); show('✅ Yes, this quote appears in the source.' if ok else '⚠️ Check again. This quote was not found in the source.'); return ok\nsafe_ai_response=ai_review_prompt=ai_review_decision_matrix=ai_answer_from_source=ai_review_script=ai_review_workflow=_fb\nstart_e4a_lab=lambda lab_id: show('### Lab helper offline\\n\\n'+M+'\\n\\nYou can still complete this lab using the regular worksheet steps in the book.')")
start_e4a_lab("class-04")

# %% [markdown]
# ## Step 2. Plan a safe project
#
# Choose one project. Change the example text, then run the cell.

# %%
# @title Step 2: Plan a safe project
project_type = "Guess the Number game"
game_goal = "The player guesses a secret number from 1 to 100."
feature_one = "The game says Too high, Too low, or Correct."
feature_two = "The game counts attempts and has a New Game button."
feature_three = "The game rejects empty and out-of-range input."

show(
    "**My project:** " + project_type + "\n\n"
    "**Goal:** " + game_goal + "\n\n"
    "**Features:**\n"
    "- " + feature_one + "\n"
    "- " + feature_two + "\n"
    "- " + feature_three
)

# %% [markdown]
# ## Step 3. Build the complete-file prompt
#
# The output below is a **prompt plan**, not game code. The complete-file
# rule is included every time.

# %%
# @title Step 3: Build the complete-file prompt
complete_file_rule = (
    "Create one complete, self-contained HTML file.\n\n"
    "Put all CSS inside a <style> element.\n"
    "Put all JavaScript inside a <script> element.\n"
    "Do not use external libraries, images, fonts, audio, or network requests.\n"
    "The file must work when I open it directly in a browser.\n\n"
    "Return the entire HTML file in one code block.\n"
    "Start with <!doctype html>.\n"
    "Do not return partial code or only the changed section."
)

complete_prompt = (
    "I want to create a " + project_type + ".\n\n"
    + "Goal: " + game_goal + "\n"
    + "Required feature 1: " + feature_one + "\n"
    + "Required feature 2: " + feature_two + "\n"
    + "Required feature 3: " + feature_three + "\n\n"
    + complete_file_rule
)

show("**My complete-file prompt:**\n\n```text\n" + complete_prompt + "\n```")

# %% [markdown]
# ## Step 4. Plan one test and bug report
#
# Write what should happen before asking AI to change anything.

# %%
# @title Step 4: Plan one test and bug report
test_action = "Leave the number input empty and select Guess."
expected_result = "The game shows a helpful message and does not add an attempt."
actual_result = "The game shows no message and adds one attempt."
bug_sentence = "The bug happens when the input is empty."

debug_prompt = (
    "Here is my current complete HTML file.\n\n"
    "I expected: " + expected_result + "\n"
    "The actual result was: " + actual_result + "\n"
    + bug_sentence + "\n\n"
    "Find the bug and correct it.\n"
    "Keep all existing working features.\n"
    "Return the complete corrected HTML file, not a fragment."
)

show(
    "**Test action:** " + test_action + "\n\n"
    "**Expected result:** " + expected_result + "\n\n"
    "**Actual result:** " + actual_result + "\n\n"
    "**Debugging request:**\n\n```text\n" + debug_prompt + "\n```"
)

# %% [markdown]
# ## Step 5. Plan manual versions
#
# Keep the last working file. Use **Save As** before a major change.

# %%
# @title Step 5: Plan manual versions
version_one = "guess-number-v1.html"
version_two = "guess-number-v2-fixed-input.html"
backup_note = "I keep Version 1 and a backup. I do not overwrite the last working file."

show(
    "**Version 1:** " + version_one + "\n\n"
    "**Version 2:** " + version_two + "\n\n"
    "**Backup habit:** " + backup_note
)

# %% [markdown]
# ## Step 6. Write a 60-second project script
#
# Aim for about 100 to 150 words.

# %%
# @title Step 6: Write a 60-second project script
project_script = (
    "Hello, my name is Student A. My project is a Guess the Number game. "
    "The user enters a number from one to one hundred and selects Guess. "
    "The game says Too high, Too low, or Correct. It also counts each attempt. "
    "Before I created the game, I wrote what should happen. Then I tested empty "
    "input. I expected a helpful message, but the actual result was no message "
    "and one extra attempt. I wrote a clear bug report and asked for one complete "
    "corrected HTML file. I saved the new result as Version 2 and kept Version 1. "
    "Next, I want to add an easy mode. Thank you for listening."
)

word_count = len([word for word in project_script.split() if word.strip()])
show("**Speaking script (" + str(word_count) + " words):**\n\n" + project_script)

# %% [markdown]
# ## Step 7. Ask AI to review the English
#
# AI can help make the script clearer, but it must not add project
# features or facts.
#
# > ⚠️ **Privacy warning:** Do not type private information. Use only the
# > safe project description.

# %%
# @title Step 7: Ask AI to review the English
ai_script_suggestion = ai_review_script(project_script)
show_ai_answer("Colab AI English suggestion", ai_script_suggestion)

# %% [markdown]
# ### Check the AI answer
#
# AI can help, but I must check it.
#
# 1.  Did AI use only safe information?
# 2.  Did AI invent anything?
# 3.  What should I verify?
# 4.  What will I keep, change, or reject?
# 5.  I make the final decision.
#
# ## Step 8. Record my AI check

# %%
# @title Step 8: Record my AI check
useful_change = "AI made one long sentence shorter."
rejected_change = "I rejected a feature that is not in my project."
next_check = "I will check that the expected and actual results are still correct."

show(
    "**Useful:** " + useful_change + "\n\n"
    "**Rejected:** " + rejected_change + "\n\n"
    "**Verify:** " + next_check
)

# %% [markdown]
# ## Step 9. Choose a pronunciation focus

# %%
# @title Step 9: Choose a pronunciation focus
pronunciation_focus = "pausing"
pronunciation_word = "JavaScript"

show(
    "**My focus:** " + pronunciation_focus + "\n\n"
    "**One word to practice:** " + pronunciation_word + "\n\n"
    "Read the script slowly. Pause after each sentence. Then time it."
)

# %% [markdown]
# ## Keep playing
#
# This lab is a **playground**. Change the project, features, test, bug,
# filenames, or speaking script and run the cells again. A working
# advanced game is optional. Nothing here is saved or graded.
#
# When you are ready, **write your real answer in the Student Workbook**
# pages in the book: `Lesson 7 - AI Game Prompt and Debug Log` and
# `Lesson 8 - Speaking Script and Consent Check`.
#
# > Remember: Plan first. Test expected behavior. Describe the actual
# > result. Save a new version. Persist.
